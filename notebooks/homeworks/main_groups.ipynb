# %%
"""
    Read a file and return its path and content.
    Process all .py files in a given directory and store their names and contents.
"""
import os

def read_file(file_path):
    try:
        with open(file_path, "r", encoding="utf-8") as file:
            content = file.read()
        return file_path, content
    except Exception as e:
        print(f"Error reading file {file_path}: {e}")
        return file_path, None

def process_files(target_directory):
    # Storage for file names and contents
    file_names = []
    file_contents = []

    # Check if the path is a valid directory
    if not os.path.isdir(target_directory):
        print(f"Error: The path '{target_directory}' is not a valid directory.")
        return file_names, file_contents
    
    for dirs in os.walk(target_directory):
        # Get the current directory path
        path = dirs[0]
        # Process the files in the directory
        for file in os.listdir(path):
            file_path = os.path.join(path, file)
            if os.path.isfile(file_path) and file.endswith(".py"):
                file_name, content = read_file(file_path)
                # Store the file name and content
                file_names.append(file_name)
                file_contents.append(content)

    return file_names, file_contents

# %%
import os

# Locate notebooks/datasets whether the kernel starts in this folder or in the repository root.
here = os.path.abspath(os.getcwd())
datasets = next(
    os.path.join(base, "datasets")
    for base in (os.path.dirname(here), here, os.path.join(here, "notebooks"))
    if os.path.isdir(os.path.join(base, "datasets"))
)
homework_directory = os.path.join(datasets, "INF-111-JT-Tarea 1-6876")
file_names, file_contents = process_files(homework_directory)

# %%
from csim.utils import group_by_exhaustive_search

# Group files by similarity, using union-find with a similarity threshold of 0.6
results = group_by_exhaustive_search(file_names, file_contents, "python_3_13", 0.6, ted_algorithm="apted")
print(results)
# Out:
# Syntax error in file /Users/edsoneddy/Projects/Personal/csim/notebooks/datasets/INF-111-JT-Tarea 1-6876/NATALIA MONICA FLORES MERCADO_94807_assignsubmission_file/PRACTICA 1.py line 1:6 mismatched input '1' expecting {';', NEWLINE}
# Syntax error in file /Users/edsoneddy/Projects/Personal/csim/notebooks/datasets/INF-111-JT-Tarea 1-6876/NATALIA MONICA FLORES MERCADO_94807_assignsubmission_file/PRACTICA 1.py line 2:19 mismatched input 'Mercado' expecting {';', NEWLINE}
# Syntax error in file /Users/edsoneddy/Projects/Personal/csim/notebooks/datasets/INF-111-JT-Tarea 1-6876/NATALIA MONICA FLORES MERCADO_94807_assignsubmission_file/PRACTICA 1.py line 2:27 mismatched input 'Natalia' expecting {';', NEWLINE}
# Syntax error in file /Users/edsoneddy/Projects/Personal/csim/notebooks/datasets/INF-111-JT-Tarea 1-6876/NATALIA MONICA FLORES MERCADO_94807_assignsubmission_file/PRACTICA 1.py line 2:35 extraneous input 'Monica' expecting {';', NEWLINE}
# Syntax error in file /Users/edsoneddy/Projects/Personal/csim/notebooks/datasets/INF-111-JT-Tarea 1-6876/NATALIA MONICA FLORES MERCADO_94807_assignsubmission_file/PRACTICA 1.py line 77:7 extraneous input '\n' expecting {FSTRING_START, '(', '[', LBRACE, '+', '-', '~', '...', 'False', 'await', 'None', 'True', 'lambda', 'not', 'type', 'match', 'case', '_', NAME, NUMBER, STRING}
# Syntax error in file /Users/edsoneddy/Projects/Personal/csim/notebooks/datasets/INF-111-JT-Tarea 1-6876/ALEXIA VALENTINA RAMIREZ GOMEZ_94876_assignsubmission_file/TAREA-PROGRAMACION(1).py line 24:0  LEXER ERROR: inconsistent dedent
# Syntax error in file /Users/edsoneddy/Projects/Personal/csim/notebooks/datasets/INF-111-JT-Tarea 1-6876/ALEXIA VALENTINA RAMIREZ GOMEZ_94876_assignsubmission_file/TAREA-PROGRAMACION(1).py line 24:7 mismatched input ' ERROR: inconsistent dedent' expecting DEDENT
# Threshold: 0.6
# Total files processed: 56
# Group 1 (Average Similarity: 0.57):
# /Users/edsoneddy/Projects/Personal/csim/notebooks/datasets/INF-111-JT-Tarea 1-6876/ROY ANDERSON GARCIA MENDOZA_94880_assignsubmission_file/tarea_ovni.py
# /Users/edsoneddy/Projects/Personal/csim/notebooks/datasets/INF-111-JT-Tarea 1-6876/REBECA ESTHER ROJAS MOREJON_94891_assignsubmission_file/Tarea1_RojasRebeca.py
# /Users/edsoneddy/Projects/Personal/csim/notebooks/datasets/INF-111-JT-Tarea 1-6876/GONZALO ULURI HUANCA_94857_assignsubmission_file/ejercicio.py
# /Users/edsoneddy/Projects/Personal/csim/notebooks/datasets/INF-111-JT-Tarea 1-6876/DYLAN ERICK MIRANDA YUJRA_94842_assignsubmission_file/problema.py
# /Users/edsoneddy/Projects/Personal/csim/notebooks/datasets/INF-111-JT-Tarea 1-6876/AARON JOSUE LLUTA PATIÑO_95997_assignsubmission_file/tarea1lluta.py
# /Users/edsoneddy/Projects/Personal/csim/notebooks/datasets/INF-111-JT-Tarea 1-6876/JOHANN EDIBERT QUISPE FLORES_94908_assignsubmission_file/cliclos for.py
# /Users/edsoneddy/Projects/Personal/csim/notebooks/datasets/INF-111-JT-Tarea 1-6876/JOSE BLADIMIR MARIN CUSI_94831_assignsubmission_file/ovni.py
# /Users/edsoneddy/Projects/Personal/csim/notebooks/datasets/INF-111-JT-Tarea 1-6876/MIGUEL FELIX CHAVEZ MACHACA_95850_assignsubmission_file/ovni.py
# /Users/edsoneddy/Projects/Personal/csim/notebooks/datasets/INF-111-JT-Tarea 1-6876/DAFNE MIA LAURA_95999_assignsubmission_file/TAREA 1.py
# /Users/edsoneddy/Projects/Personal/csim/notebooks/datasets/INF-111-JT-Tarea 1-6876/JHESENIA ADRIANA MAYTA GUARACHI_94901_assignsubmission_file/tarea1.py
# /Users/edsoneddy/Projects/Personal/csim/notebooks/datasets/INF-111-JT-Tarea 1-6876/SANDRO MORALES GUTIERREZ_94814_assignsubmission_file/tarea1.py
# /Users/edsoneddy/Projects/Personal/csim/notebooks/datasets/INF-111-JT-Tarea 1-6876/JOEL MARCEL MAMANI ESCOBAR_94887_assignsubmission_file/tarea.py
# /Users/edsoneddy/Projects/Personal/csim/notebooks/datasets/INF-111-JT-Tarea 1-6876/OLVER SIÑANI SIÑANI_94851_assignsubmission_file/TAREA1.py
# /Users/edsoneddy/Projects/Personal/csim/notebooks/datasets/INF-111-JT-Tarea 1-6876/YAMIL DYLAN LUNA QUISPE_94849_assignsubmission_file/Tarea 1_13245595.py
# /Users/edsoneddy/Projects/Personal/csim/notebooks/datasets/INF-111-JT-Tarea 1-6876/DAVID ANGEL MAMANI ASPI_95758_assignsubmission_file/Ataqueovni.py
# /Users/edsoneddy/Projects/Personal/csim/notebooks/datasets/INF-111-JT-Tarea 1-6876/ALEJANDRO ARGANA FLORES_94856_assignsubmission_file/Tarea Ovnis.py
# /Users/edsoneddy/Projects/Personal/csim/notebooks/datasets/INF-111-JT-Tarea 1-6876/BENJAMIN JHONATAN PAZ MAMANI_95761_assignsubmission_file/tarea1.py
# Group 2 (Average Similarity: 0.61):
# /Users/edsoneddy/Projects/Personal/csim/notebooks/datasets/INF-111-JT-Tarea 1-6876/CARLOS ANDRES ORTIZ BALTAZAR_94882_assignsubmission_file/practica.py
# /Users/edsoneddy/Projects/Personal/csim/notebooks/datasets/INF-111-JT-Tarea 1-6876/LIZETH ALMA HUANCA GUTIERREZ_94863_assignsubmission_file/Tarea Ovnis.py
# /Users/edsoneddy/Projects/Personal/csim/notebooks/datasets/INF-111-JT-Tarea 1-6876/DANNER ALEJANDRO ORTIZ CORO_94809_assignsubmission_file/tarea derribar ovnis.py
# /Users/edsoneddy/Projects/Personal/csim/notebooks/datasets/INF-111-JT-Tarea 1-6876/CELINA NAYLA ASTURIZAGA CADENA_94812_assignsubmission_file/ASTURIZAGA CADENA CELINA NAYLA TAREA1.py
# /Users/edsoneddy/Projects/Personal/csim/notebooks/datasets/INF-111-JT-Tarea 1-6876/JOSE APAZA GAILE_94845_assignsubmission_file/ApazaGaile.py
# /Users/edsoneddy/Projects/Personal/csim/notebooks/datasets/INF-111-JT-Tarea 1-6876/KEVIN BRANDON ESTRADA SILVESTRE_94871_assignsubmission_file/Tarea del ovni.py
# /Users/edsoneddy/Projects/Personal/csim/notebooks/datasets/INF-111-JT-Tarea 1-6876/DIEGO ANTONY MERCADO AGNE_95755_assignsubmission_file/diego.py.py
# /Users/edsoneddy/Projects/Personal/csim/notebooks/datasets/INF-111-JT-Tarea 1-6876/MEYBOL YARA GUTIERREZ CALLE_95848_assignsubmission_file/TAREA1.py
# /Users/edsoneddy/Projects/Personal/csim/notebooks/datasets/INF-111-JT-Tarea 1-6876/HENRY QUISPE ULO_94870_assignsubmission_file/Tarea.py
# /Users/edsoneddy/Projects/Personal/csim/notebooks/datasets/INF-111-JT-Tarea 1-6876/ANDRE YAMIL HUAYGUA CORDERO_94895_assignsubmission_file/Tarea.py
# /Users/edsoneddy/Projects/Personal/csim/notebooks/datasets/INF-111-JT-Tarea 1-6876/VLADIMIR ESPINOZA CATACORA_94850_assignsubmission_file/ovnis2.py
# /Users/edsoneddy/Projects/Personal/csim/notebooks/datasets/INF-111-JT-Tarea 1-6876/MAYCOL ALAN TICONA QUISPE_94893_assignsubmission_file/Tarea_ovni_super_pro.py
# /Users/edsoneddy/Projects/Personal/csim/notebooks/datasets/INF-111-JT-Tarea 1-6876/ANGEL JUAN JOSE BUTRON ROMERO_95849_assignsubmission_file/ovnis_laser.py
# /Users/edsoneddy/Projects/Personal/csim/notebooks/datasets/INF-111-JT-Tarea 1-6876/RUT BELEN MOLLO VELASCO_94821_assignsubmission_file/programacion.py
# /Users/edsoneddy/Projects/Personal/csim/notebooks/datasets/INF-111-JT-Tarea 1-6876/RUTH ESTHER QUIROGA FLORES_94810_assignsubmission_file/tarea1_esther_1.py
# /Users/edsoneddy/Projects/Personal/csim/notebooks/datasets/INF-111-JT-Tarea 1-6876/IGNACIO CORTEZ MANSILLA_94906_assignsubmission_file/tarea.py
# /Users/edsoneddy/Projects/Personal/csim/notebooks/datasets/INF-111-JT-Tarea 1-6876/JOEL JONATAN CHURA ARROYO_95753_assignsubmission_file/ovnis.py
# Group 3 (Average Similarity: 0.82):
# /Users/edsoneddy/Projects/Personal/csim/notebooks/datasets/INF-111-JT-Tarea 1-6876/NATALIA MONICA FLORES MERCADO_94807_assignsubmission_file/PRACTICA 1.py
# /Users/edsoneddy/Projects/Personal/csim/notebooks/datasets/INF-111-JT-Tarea 1-6876/ALEXIA VALENTINA RAMIREZ GOMEZ_94876_assignsubmission_file/TAREA-PROGRAMACION(1).py
# Unique Files (similarity below threshold):
# /Users/edsoneddy/Projects/Personal/csim/notebooks/datasets/INF-111-JT-Tarea 1-6876/FABIAN PAULO ALVAREZ POMA_94868_assignsubmission_file/Tarea_1.py
# /Users/edsoneddy/Projects/Personal/csim/notebooks/datasets/INF-111-JT-Tarea 1-6876/YULIANA ANETTE SUXO VILLANUEVA_94875_assignsubmission_file/solucion.py
# /Users/edsoneddy/Projects/Personal/csim/notebooks/datasets/INF-111-JT-Tarea 1-6876/MATIAS AUGUSTO MOLLO CHINO_96000_assignsubmission_file/tarea1.py
# /Users/edsoneddy/Projects/Personal/csim/notebooks/datasets/INF-111-JT-Tarea 1-6876/WILY AARON QUISPE ALANOCA_95759_assignsubmission_file/wilyquispe.py
# /Users/edsoneddy/Projects/Personal/csim/notebooks/datasets/INF-111-JT-Tarea 1-6876/VICTOR LUIS TELLERIA QUIROGA_94816_assignsubmission_file/tarea.py
# /Users/edsoneddy/Projects/Personal/csim/notebooks/datasets/INF-111-JT-Tarea 1-6876/MARIA VALENTINA TOCONAS CHAVEZ_94808_assignsubmission_file/tarea1.py
# /Users/edsoneddy/Projects/Personal/csim/notebooks/datasets/INF-111-JT-Tarea 1-6876/WARA ISIS VELASQUEZ MIRANDA_95756_assignsubmission_file/Tarea 1 - Wara Isis Velasquez Miranda.py
# /Users/edsoneddy/Projects/Personal/csim/notebooks/datasets/INF-111-JT-Tarea 1-6876/Kevin Braulio Mamani Vargas_94889_assignsubmission_file/tarea111.py
# /Users/edsoneddy/Projects/Personal/csim/notebooks/datasets/INF-111-JT-Tarea 1-6876/GABRIEL BISMAR POMA RIOS_94829_assignsubmission_file/tarea1 Gabriel Bismar Poma Rios.py
# /Users/edsoneddy/Projects/Personal/csim/notebooks/datasets/INF-111-JT-Tarea 1-6876/VALENTINA CUADROS CASTELO_94848_assignsubmission_file/ovnis3.py
# /Users/edsoneddy/Projects/Personal/csim/notebooks/datasets/INF-111-JT-Tarea 1-6876/EDILSON BEIMAR SUCA ROMAN_94813_assignsubmission_file/tareaInvasionOvni.py
# /Users/edsoneddy/Projects/Personal/csim/notebooks/datasets/INF-111-JT-Tarea 1-6876/SERGIO RONALDO MAMANI CALSINA_94873_assignsubmission_file/TAREA_1.py
# /Users/edsoneddy/Projects/Personal/csim/notebooks/datasets/INF-111-JT-Tarea 1-6876/ALBERT JOOEL JIMENEZ CUENCA_94817_assignsubmission_file/tarea1.py
# /Users/edsoneddy/Projects/Personal/csim/notebooks/datasets/INF-111-JT-Tarea 1-6876/NELSON GABRIEL VALDA SALAS_95760_assignsubmission_file/practica1.py
# /Users/edsoneddy/Projects/Personal/csim/notebooks/datasets/INF-111-JT-Tarea 1-6876/GUIDO CONDORI MIRANDA_94841_assignsubmission_file/Tarea_1.py
# /Users/edsoneddy/Projects/Personal/csim/notebooks/datasets/INF-111-JT-Tarea 1-6876/ALEXANDER ELEAZAR CONDE ORDOÑEZ_94843_assignsubmission_file/tarea1ByAlex.py
# /Users/edsoneddy/Projects/Personal/csim/notebooks/datasets/INF-111-JT-Tarea 1-6876/RODRIGO BRIAN SAAVEDRA MEJIA_94910_assignsubmission_file/Tarea 1 ovnis.py
# /Users/edsoneddy/Projects/Personal/csim/notebooks/datasets/INF-111-JT-Tarea 1-6876/CRISTOPHER ALEXIS YUJRA TICONA_95757_assignsubmission_file/Tarea 1.py
# /Users/edsoneddy/Projects/Personal/csim/notebooks/datasets/INF-111-JT-Tarea 1-6876/CRISTIAN REYNALDO ACARAPI QUINTANA_94822_assignsubmission_file/Tarea 1.py
# /Users/edsoneddy/Projects/Personal/csim/notebooks/datasets/INF-111-JT-Tarea 1-6876/ARIEL ORLANDO BUSTILLOS CADENA_95998_assignsubmission_file/ovnis2.py
