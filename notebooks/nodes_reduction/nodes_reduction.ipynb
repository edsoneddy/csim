# %% [markdown]
# ## Nodes Reduction Analysis (Python)
#
# How many nodes does a program have before and after csim's normalization + pruning + hashing?
# **Run all cells**: this notebook selects the programs, counts the nodes, draws every chart and writes
# `../RESULTS.md`. Nothing else has to be run.
#
# * **Before**: every node of the raw ANTLR parse tree (rules and tokens).
# * **After**: the tree handed to the tree edit distance (`csim tree` prints it as "Total nodes after pruning"),
#   both from `csim.count_nodes`.
# * **Sample**: real judge submissions from `all_py` (problems pooled) with duplicates, syntax errors, programs that
#   hard-code big collections, trivial programs and size outliers removed. To get a realistic, compact distribution
#   the `TARGET` (1000) programs closest in size to `TARGET_NODES` raw nodes are kept (at most `MAX_PER_PROBLEM`
#   per problem, so no exercise dominates), instead of sampling the whole size range.
#
# Requires the dataset folder `jv-umsa-dataset` (it must contain `all_py`); set `DATASETS_ROOT` below or the
# `CSIM_DATASETS` environment variable if it is not next to the repository.

# %%
# %matplotlib inline
import ast
import contextlib
import csv
import hashlib
import io
import os
import statistics as st
from pathlib import Path

import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from antlr4.tree.Tree import TerminalNode

from csim import count_nodes
from csim.language.parser import ANTLR_parse
from csim.utils import get_similarity_coefficient, group_by_exhaustive_search, preprocess_code, read_file

# ---- configuration -------------------------------------------------------------------------
GRAMMARS = ("python_3_13", "python_3")   # both are analysed; the first is the primary one in the report
TARGET = 1000            # number of programs to analyse (a round number)
TARGET_NODES = 1000      # programs closest to this many raw nodes (primary grammar) are the ones analysed
MAX_PER_PROBLEM = 15     # cap of programs per problem (raised only if TARGET cannot be reached)
MIN_NODES = 40           # drop trivial programs (raw nodes, in every grammar)
FENCE = 3.0              # drop size outliers above Q3 + FENCE * IQR (computed per grammar)
MAX_LITERAL = 20         # drop programs with a list/tuple/set/dict literal of at least this many elements
COLOR_BEFORE, COLOR_AFTER = "#3498db", "#e67e22"


def find_dir(name, candidates):
    for c in candidates:
        if c and Path(c, name).is_dir():
            return Path(c).resolve()
    raise FileNotFoundError(f"could not find '{name}'; set DATASETS_ROOT / CSIM_DATASETS")


# Works whether the kernel starts in this folder or in the repository root.
HERE = find_dir("results", [".", "notebooks/nodes_reduction"]) if Path("results").is_dir() or Path("notebooks/nodes_reduction/results").is_dir() else Path(".").resolve()
NB_DIR = HERE if (HERE / "results").is_dir() else Path("notebooks/nodes_reduction").resolve()
NB_DIR.joinpath("results").mkdir(exist_ok=True)
RESULTS = NB_DIR / "results"
DATASETS_ROOT = find_dir("all_py", [os.environ.get("CSIM_DATASETS"), NB_DIR / "../../../jv-umsa-dataset", NB_DIR / "../../../../jv-umsa-dataset", Path.home() / "Projects/Personal/jv-umsa-dataset"])
ALL_PY = DATASETS_ROOT / "all_py"
print("dataset:", ALL_PY)
print("output :", RESULTS)
# Out:
# dataset: /Users/edsoneddy/Projects/Personal/jv-umsa-dataset/all_py
# output : /Users/edsoneddy/Projects/Personal/csim/notebooks/nodes_reduction/results

# %% [markdown]
# ### 1. Select the programs
#
# A program is kept when it parses without syntax errors in **both** grammars. Two programs are duplicates when
# their raw ANTLR trees have the same shape (same sequence of rule/token types), i.e. they differ only in
# names, literals, comments or whitespace. Problems are pooled (only node counts are analysed). Among the
# remaining programs, the `TARGET` closest to `TARGET_NODES` raw nodes (in the primary grammar) are selected, taking
# at most `MAX_PER_PROBLEM` from each problem; the cap is raised only as much as needed to reach `TARGET`.

# %%
def raw_shape(tree):
    """(hash of the shape, node count) of a raw ANTLR tree; iterative because trees can be very deep."""
    labels, stack = [], [tree]
    while stack:
        node = stack.pop()
        n = node.getChildCount()
        labels.append(-node.symbol.type - 2 if isinstance(node, TerminalNode) else node.getRuleIndex())
        labels.append(n)
        stack.extend(node.getChild(i) for i in range(n - 1, -1, -1))
    return hashlib.sha1(repr(labels).encode()).hexdigest(), len(labels) // 2


def has_big_literal(text, limit=MAX_LITERAL):
    """True when the program hard-codes a collection (list/tuple/set/dict display) of >= `limit` elements:
    mostly data, and a huge tree that says nothing about the program's structure."""
    try:
        module = ast.parse(text)
    except (SyntaxError, ValueError, RecursionError):  # e.g. Python 2 code: fall back to counting commas
        return any(line.count(",") >= limit for line in text.splitlines())
    for node in ast.walk(module):
        if isinstance(node, (ast.List, ast.Tuple, ast.Set)) and len(node.elts) >= limit:
            return True
        if isinstance(node, ast.Dict) and len(node.keys) >= limit:
            return True
    return False


def analyse(path):
    """(shape, {grammar: raw_nodes}, lines, text), or None when the file is unusable."""
    try:
        text = path.read_text(encoding="utf-8")
    except (UnicodeDecodeError, OSError):
        return None
    if not text.strip():
        return None
    shape, counts = None, {}
    for grammar in GRAMMARS:
        errors = io.StringIO()
        try:
            with contextlib.redirect_stderr(errors):
                tree = ANTLR_parse(str(path), text, grammar)
        except Exception:
            return None
        if errors.getvalue():        # any syntax error: the file says nothing about pruning
            return None
        digest, counts[grammar] = raw_shape(tree)
        shape = shape or digest
    return shape, counts, text.count("\n") + 1, text


def select_programs():
    # The native parser recovers from syntax errors silently; the pure-Python one reports them.
    os.environ["CSIM_DISABLE_NATIVE"] = "1"
    try:
        pool, seen, stats = {}, set(), {"parsed_clean_unique": 0, "big_literal": 0}
        for problem in sorted(p for p in ALL_PY.iterdir() if p.is_dir()):
            unique = {}
            for f in sorted(problem.glob("*.py")):
                info = analyse(f)
                if info is None:
                    continue
                shape, counts, lines, text = info
                if shape in unique or shape in seen:
                    continue
                seen.add(shape)
                if has_big_literal(text):
                    stats["big_literal"] += 1
                    continue
                unique[shape] = (counts, lines, f.name)
            pool[problem.name] = list(unique.values())
    finally:
        os.environ.pop("CSIM_DISABLE_NATIVE", None)

    stats["parsed_clean_unique"] = sum(len(v) for v in pool.values())
    limits = {}
    for g in GRAMMARS:                       # a grammar with deeper trees reaches big counts first
        sizes = sorted(c[0][g] for v in pool.values() for c in v)
        q1, q3 = sizes[len(sizes) // 4], sizes[3 * len(sizes) // 4]
        limits[g] = q3 + FENCE * (q3 - q1)
    ok = lambda c: all(MIN_NODES <= c[0][g] <= limits[g] for g in GRAMMARS)
    pool = {p: sorted((c for c in v if ok(c)), key=lambda c: c[0][GRAMMARS[0]]) for p, v in pool.items()}
    pool = {p: v for p, v in pool.items() if v}
    stats["after_size_filter"] = sum(len(v) for v in pool.values())
    stats["limits"] = {g: round(limits[g]) for g in GRAMMARS}

    primary = GRAMMARS[0]
    ranked = sorted(
        ((abs(c[0][primary] - TARGET_NODES), problem, c[2], c[1]) for problem, v in pool.items() for c in v)
    )
    cap = MAX_PER_PROBLEM
    while True:
        taken, per_problem = [], {}
        for _, problem, name, lines in ranked:
            if per_problem.get(problem, 0) < cap:
                taken.append((problem, name, lines))
                per_problem[problem] = per_problem.get(problem, 0) + 1
                if len(taken) == TARGET:
                    break
        if len(taken) == TARGET or cap >= len(ranked):
            break
        cap += 1
    stats["per_problem_cap"] = cap
    return taken, stats


selected, sel_stats = select_programs()
with open(RESULTS / "selected_all_py.csv", "w", newline="") as fh:
    w = csv.writer(fh)
    w.writerow(["problem", "file", "lines"])
    w.writerows(selected)
print(f"{len(selected)} programs from {len({r[0] for r in selected})} problems")
print(sel_stats)
# Out:
# 1000 programs from 160 problems
# {'parsed_clean_unique': 4665, 'big_literal': 32, 'after_size_filter': 4623, 'limits': {'python_3_13': 3321, 'python_3': 1881}, 'per_problem_cap': 15}

# %% [markdown]
# ### 2. Count the nodes before and after pruning

# %%
counts = {g: [] for g in GRAMMARS}
for problem, name, lines in selected:
    path = ALL_PY / problem / name
    text = path.read_text(encoding="utf-8")
    for g in GRAMMARS:
        with contextlib.redirect_stderr(io.StringIO()):
            counts[g].append((problem, name, lines, *count_nodes(str(path), text, g)))

for g in GRAMMARS:
    with open(RESULTS / f"nodes_{g}.csv", "w", newline="") as fh:
        w = csv.writer(fh)
        w.writerow(["problem", "file", "lines", "before", "after"])
        w.writerows(counts[g])
    print(g, len(counts[g]), "programs")
# Out:
# python_3_13 1000 programs
# python_3 1000 programs

# %% [markdown]
# ### 3. Charts (real node count, one chart per image)

# %%
def arrays(g):
    return np.array([r[3] for r in counts[g]]), np.array([r[4] for r in counts[g]])


def summary(g):
    before, after = arrays(g)
    print(f"{g}: {len(before)} programs")
    print(f"  nodes before  mean {before.mean():7.1f}  median {np.median(before):6.0f}  p90 {np.percentile(before, 90):6.0f}  max {before.max()}")
    print(f"  nodes after   mean {after.mean():7.1f}  median {np.median(after):6.0f}  p90 {np.percentile(after, 90):6.0f}  max {after.max()}")
    print(f"  average reduction {(1 - after.mean() / before.mean()) * 100:.2f}%  (x{before.mean() / after.mean():.1f}); "
          f"median per-program x{np.median(before / after):.1f}; left with a single node: {(after <= 1).sum()}")


def _save(fig, name):
    fig.tight_layout()
    fig.savefig(RESULTS / name, dpi=150)
    plt.show()


def hist_plot(g, title):
    before, after = arrays(g)
    fig, ax = plt.subplots(figsize=(10, 6))
    bins = np.linspace(0, max(after.max(), before.max()), 80)
    sns.histplot(before, bins=bins, color=COLOR_BEFORE, label="Antes de la normalización y poda", element="step", alpha=0.3, ax=ax)
    sns.histplot(after, bins=bins, color=COLOR_AFTER, label="Después de la normalización y poda", element="step", alpha=0.3, ax=ax)
    ax.axvline(before.mean(), color=COLOR_BEFORE, linestyle="--", linewidth=2, label=f"Media antes {before.mean():.1f}")
    ax.axvline(after.mean(), color=COLOR_AFTER, linestyle="--", linewidth=2, label=f"Media después {after.mean():.1f}")
    ax.set_xlabel("Número de nodos")
    ax.set_ylabel("Número de programas")
    ax.set_ylim(0, len(before))    # the y axis spans all n programs, not just the tallest bin
    ax.set_title(f"{title}: distribución del número de nodos (n={len(before)})")
    ax.legend(loc="upper center")
    _save(fig, f"nodes_hist_real_{g}.png")


def scatter_plot(g, title):
    before, after = arrays(g)
    fig, ax = plt.subplots(figsize=(8, 7))
    ax.scatter(before, after, s=10, alpha=0.35, color="#8e44ad")
    top = before.max() * 1.05
    for ratio, style in ((10, "--"), (20, "-."), (40, ":")):
        ax.plot([0, top], [0, top / ratio], style, color="gray", linewidth=1, label=f"reducción x{ratio}")
    ax.set_xlim(0, top)
    ax.set_ylim(0, after.max() * 1.1)
    ax.set_xlabel("Nodos antes")
    ax.set_ylabel("Nodos después")
    ax.set_title(f"{title}: un punto por programa")
    ax.legend()
    _save(fig, f"nodes_scatter_{g}.png")


TITLES = {"python_3_13": "Python 3.13", "python_3": "Python 3"}
for g in GRAMMARS:
    summary(g)
    hist_plot(g, TITLES[g])
    scatter_plot(g, TITLES[g])
# Out:
# python_3_13: 1000 programs
#   nodes before  mean   987.7  median    987  p90   1117  max 1186
#   nodes after   mean    26.5  median     26  p90     34  max 52
#   average reduction 97.32%  (x37.3); median per-program x37.4; left with a single node: 0
# python_3: 1000 programs
#   nodes before  mean   582.3  median    583  p90    661  max 778
#   nodes after   mean    29.6  median     29  p90     39  max 60
#   average reduction 94.91%  (x19.7); median per-program x19.9; left with a single node: 0

# %%
# Both grammars side by side: how much of each program survives pruning.
fig, ax = plt.subplots(figsize=(9, 5))
for g, color in zip(GRAMMARS, ("#2c3e50", "#16a085")):
    before, after = arrays(g)
    sns.ecdfplot(after / before * 100, ax=ax, color=color, linewidth=2, label=f"{g} (mediana {np.median(after / before * 100):.1f}%)")
ax.set_xlabel("Nodos que sobreviven a la poda (% del árbol crudo)")
ax.set_ylabel("Proporción acumulada de programas")
ax.set_title("Reducción de nodos por programa")
ax.legend()
_save(fig, "nodes_survival_python.png")

# %% [markdown]
# ### 4. Report (`../RESULTS.md`)
#
# Node tables plus the homework results of `../homeworks` (`main_all.ipynb` / `main_groups.ipynb`).

# %%
def pct(values, q):
    values = sorted(values)
    return values[min(len(values) - 1, round(q / 100 * (len(values) - 1)))]


THRESHOLD = 0.6
HOMEWORK = next(p for p in (NB_DIR.parent / "datasets" / "INF-111-JT-Tarea 1-6876",) if p.is_dir())

md = ["# Notebook results", "", "Generated by `nodes_reduction/nodes_reduction.ipynb`; do not edit by hand.", "",
      "## Node reduction (Python)", "",
      f"Sample: **{len(selected)} programs** from `all_py` ({len({r[0] for r in selected})} problems pooled), duplicate-free "
      "(same raw ANTLR tree shape counted once), without syntax errors in either grammar, without programs that hard-code a "
      f"collection literal of {MAX_LITERAL}+ elements, trivial programs (< {MIN_NODES} nodes) or size outliers (judged in each grammar). "
      f"To keep the distribution compact and realistic, the {TARGET} programs closest to {TARGET_NODES} raw nodes ({GRAMMARS[0]}) were kept, at most {sel_stats['per_problem_cap']} per problem. "
      "*Before* = nodes of the raw ANTLR tree; *after* = nodes of the normalized, pruned and hashed tree given to the tree edit distance.", "",
      "| Grammar | Programs | Before (mean / median / p90 / max) | After (mean / median / p90 / max) | Mean reduction | Median per-program ratio | Left with 1 node |",
      "|---|---|---|---|---|---|---|"]
for g in GRAMMARS:
    b, a = (x.tolist() for x in arrays(g))   # plain Python ints: statistics.mean truncates numpy ints
    md.append(f"| `{g}` | {len(b)} | {st.mean(b):.0f} / {st.median(b):.0f} / {pct(b, 90)} / {max(b)} "
              f"| {st.mean(a):.1f} / {st.median(a):.0f} / {pct(a, 90)} / {max(a)} "
              f"| {(1 - st.mean(a) / st.mean(b)) * 100:.1f}% (x{st.mean(b) / st.mean(a):.1f}) "
              f"| x{st.median([x / y for x, y in zip(b, a)]):.1f} | {sum(v <= 1 for v in a)} |")
md += ["", "Figures are in `nodes_reduction/results/`, all on the real (linear) node count: per grammar the distribution and a per-program scatter, "
       "plus one chart comparing both grammars.", ""]
for g in GRAMMARS:
    md += [f"### `{g}`", "", f"![distribution](nodes_reduction/results/nodes_hist_real_{g}.png)", "",
           f"![scatter](nodes_reduction/results/nodes_scatter_{g}.png)", ""]
md += ["### Both grammars", "", "![survival](nodes_reduction/results/nodes_survival_python.png)", ""]

# ---- homework similarity
names, contents = [], []
for path in sorted(HOMEWORK.rglob("*.py")):
    name, content = read_file(str(path))
    if content is not None:
        names.append(name)
        contents.append(content)
with contextlib.redirect_stderr(io.StringIO()):
    processed = [preprocess_code(n, c, "python_3_13") for n, c in zip(names, contents)]
    groups, avgs, uniques, _ = group_by_exhaustive_search(names, contents, "python_3_13", THRESHOLD, "apted", printable_output=False)
sims = [get_similarity_coefficient(processed[i], processed[j], "apted") for i in range(len(names)) for j in range(i + 1, len(names))]
md += ["## Homework similarity (`homeworks/main_all.ipynb`, `main_groups.ipynb`)", "",
       f"Dataset `{HOMEWORK.name}` with `python_3_13` and APTED: **{len(names)} files**, **{len(sims)} pairs**.", "",
       "| Statistic | Value |", "|---|---|",
       f"| Mean similarity | {st.mean(sims):.3f} |", f"| Median similarity | {st.median(sims):.2f} |",
       f"| p90 / max | {pct(sims, 90):.2f} / {max(sims):.2f} |",
       f"| Pairs above {THRESHOLD} | {sum(s > THRESHOLD for s in sims)} ({sum(s > THRESHOLD for s in sims) / len(sims) * 100:.1f}%) |",
       f"| Pairs above 0.8 | {sum(s > 0.8 for s in sims)} |", "",
       f"Grouping at threshold {THRESHOLD} (union-find): **{len(groups)} group(s)** with more than one file, {len(uniques)} unique files.", ""]
if groups:
    md += ["| Group | Files | Average similarity |", "|---|---|---|"]
    md += [f"| {k} | {len(g)} | {avg:.2f} |" for k, (g, avg) in enumerate(zip(groups, avgs), 1)]
    md += ["", "Groups are built with union-find, so similarity can chain: a group's average (each member against its first file) "
           "may fall below the threshold.", ""]
report = "\n".join(md)
(NB_DIR.parent / "RESULTS.md").write_text(report)
from IPython.display import Markdown
Markdown(report)
# Out:
# # Notebook results
#
# Generated by `nodes_reduction/nodes_reduction.ipynb`; do not edit by hand.
#
# ## Node reduction (Python)
#
# Sample: **1000 programs** from `all_py` (160 problems pooled), duplicate-free (same raw ANTLR tree shape counted once), without syntax errors in either grammar, without programs that hard-code a collection literal of 20+ elements, trivial programs (< 40 nodes) or size outliers (judged in each grammar). To keep the distribution compact and realistic, the 1000 programs closest to 1000 raw nodes (python_3_13) were kept, at most 15 per problem. *Before* = nodes of the raw ANTLR tree; *after* = nodes of the normalized, pruned and hashed tree given to the tree edit distance.
#
# | Grammar | Programs | Before (mean / median / p90 / max) | After (mean / median / p90 / max) | Mean reduction | Median per-program ratio | Left with 1 node |
# |---|---|---|---|---|---|---|
# ...
