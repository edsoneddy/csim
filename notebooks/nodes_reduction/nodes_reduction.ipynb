# %% [markdown]
# ## Nodes Reduction Analysis (Python)
#
# How many nodes does a program have before and after csim's normalization + pruning + hashing?
#
# * **Before**: every node of the raw ANTLR parse tree (rules and tokens).
# * **After**: the tree handed to the tree edit distance (`csim tree` prints it as "Total nodes after pruning").
#
# Both come from `csim.count_nodes`. The programs are a duplicate-free sample of real judge
# submissions from `all_py` (problems pooled; files with syntax errors, trivial programs and size
# outliers removed; exactly 1000 files) -- see `select_files.py`. To regenerate the data:
#
# ```
# python select_files.py <jv-umsa-dataset>/all_py python_3 results/selected_all_py.csv --also-check python_3_13 --target 1000
# python nodes_number.py <jv-umsa-dataset>
# ```

# %%
# %matplotlib inline
import csv
from pathlib import Path

import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

RESULTS = Path("results")
COLOR_BEFORE, COLOR_AFTER = "#3498db", "#e67e22"


def load(lang):
    with open(RESULTS / f"nodes_{lang}.csv", newline="") as fh:
        rows = list(csv.DictReader(fh))
    before = np.array([int(r["before"]) for r in rows])
    after = np.array([int(r["after"]) for r in rows])
    return before, after


def summary(lang, before, after):
    print(f"{lang}: {len(before)} programs")
    print(f"  nodes before  mean {before.mean():7.1f}  median {np.median(before):6.0f}  p90 {np.percentile(before, 90):6.0f}  max {before.max()}")
    print(f"  nodes after   mean {after.mean():7.1f}  median {np.median(after):6.0f}  p90 {np.percentile(after, 90):6.0f}  max {after.max()}")
    print(f"  average reduction {(1 - after.mean() / before.mean()) * 100:.2f}%  "
          f"(x{before.mean() / after.mean():.1f}); median per-program x{np.median(before / after):.1f}")
    print(f"  programs left with a single node: {(after <= 1).sum()}")

# %%
def _save(fig, name):
    fig.tight_layout()
    fig.savefig(RESULTS / name, dpi=150)
    plt.show()


def hist_plot(before, after, title, log, name):
    """One histogram per image; `log` switches between log-spaced bins/axis and the real node count."""
    fig, ax = plt.subplots(figsize=(10, 6))
    hi = max(after.max(), before.max())
    if log:
        bins = np.logspace(np.log10(min(after.min(), before.min())), np.log10(hi), 45)
    else:
        bins = np.linspace(0, hi, 80)
    sns.histplot(before, bins=bins, color=COLOR_BEFORE, label="Antes de la normalización y poda",
                 element="step", alpha=0.3, ax=ax)
    sns.histplot(after, bins=bins, color=COLOR_AFTER, label="Después de la normalización y poda",
                 element="step", alpha=0.3, ax=ax)
    ax.axvline(before.mean(), color=COLOR_BEFORE, linestyle="--", linewidth=2, label=f"Media antes {before.mean():.1f}")
    ax.axvline(after.mean(), color=COLOR_AFTER, linestyle="--", linewidth=2, label=f"Media después {after.mean():.1f}")
    if log:
        ax.set_xscale("log")
        ax.set_xlabel("Número de nodos (escala log)")
    else:
        ax.set_xlabel("Número de nodos (escala real)")
    ax.set_ylabel("Número de programas")
    ax.set_title(f"{title}: distribución del número de nodos (n={len(before)})")
    ax.legend()
    _save(fig, name)


def scatter_plot(before, after, title, name):
    fig, ax = plt.subplots(figsize=(8, 6.5))
    ax.scatter(before, after, s=10, alpha=0.35, color="#8e44ad")
    lim = [before.min() * 0.8, before.max() * 1.2]
    for ratio, style in ((5, ":"), (10, "--"), (20, "-."), (50, "-")):
        ax.plot(lim, [v / ratio for v in lim], style, color="gray", linewidth=1, label=f"reducción x{ratio}")
    ax.set_xlim(lim)
    ax.set_ylim(max(after.min() * 0.7, 0.8), after.max() * 1.6)
    ax.set_xscale("log")
    ax.set_yscale("log")
    ax.set_xlabel("Nodos antes (escala log)")
    ax.set_ylabel("Nodos después (escala log)")
    ax.set_title(f"{title}: un punto por programa")
    ax.legend()
    _save(fig, name)


def plot_reduction(lang, title):
    before, after = load(lang)
    summary(lang, before, after)
    hist_plot(before, after, title, log=True, name=f"nodes_hist_log_{lang}.png")
    hist_plot(before, after, title, log=False, name=f"nodes_hist_real_{lang}.png")
    scatter_plot(before, after, title, name=f"nodes_scatter_{lang}.png")


plot_reduction("python_3_13", "Python 3.13")
# Out:
# python_3_13: 1000 programs
#   nodes before  mean  1127.0  median    965  p90   2071  max 3877
#   nodes after   mean    28.7  median     25  p90     52  max 104
#   average reduction 97.45%  (x39.2); median per-program x38.2
#   programs left with a single node: 1

# %%
plot_reduction("python_3", "Python 3")
# Out:
# python_3: 1000 programs
#   nodes before  mean   654.3  median    574  p90   1206  max 1890
#   nodes after   mean    32.7  median     28  p90     61  max 141
#   average reduction 95.00%  (x20.0); median per-program x20.2
#   programs left with a single node: 1

# %%
# Both grammars side by side: how much of each program survives pruning.
fig, ax = plt.subplots(figsize=(9, 5))
for lang, color in (("python_3_13", "#2c3e50"), ("python_3", "#16a085")):
    before, after = load(lang)
    sns.ecdfplot(after / before * 100, ax=ax, color=color, linewidth=2, label=f"{lang} (mediana {np.median(after / before * 100):.1f}%)")
ax.set_xlabel("Nodos que sobreviven a la poda (% del árbol crudo)")
ax.set_ylabel("Proporción acumulada de programas")
ax.set_title("Reducción de nodos por programa")
ax.legend()
fig.tight_layout()
fig.savefig(RESULTS / "nodes_survival_python.png", dpi=150)
plt.show()
